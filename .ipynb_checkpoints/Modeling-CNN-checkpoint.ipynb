# %%
import seaborn as sns

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
import matplotlib.pyplot as plt
from joblib import load, dump
import pandas as pd
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
model_log = load("Objects/Models/model_log.joblib")

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
y = torch.load("Objects/Data/labels.pt")
X = torch.load("Objects/Data/padded_glove_embeddings.pt")

# %%
class Data(Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y
        self.n_samples = X.size(0)
        
    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]
    
    def __len__(self):
        return self.n_samples

# %%
data = Data(X, y)

# %%
train_data, test_data = random_split(data, [4000, 846])

# %%
batch_size=5

# %%
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_data, batch_size=batch_size, shuffle=False)

# %%
# define model architechture
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1,1,(3,300), stride=1)
        self.conv2 = nn.Conv2d(1,1,(2,1), stride=1)
        self.conv3 = nn.Conv1d(1,1,(3,300), stride=1)
        self.pool1 = nn.MaxPool2d((4,1))
        self.pool2 = nn.AvgPool2d((4,1))
        
        self.activation = nn.ReLU()
        
        self.flat = nn.Flatten()
        self.linear1 = nn.Linear(21, 64)
        self.linear2 = nn.Linear(64, 64)
        self.linear3 = nn.Linear(64, 3)
        
        self.dropout = nn.Dropout(p=0.2)
    def forward(self, x):
        
        output = self.conv1(x)
        output = self.pool2(output)
        # output = self.conv2(output)
        # output = self.pool2(output)
        output = self.flat(output)
        output = self.linear1(output)
        output = self.dropout(output)
        output = self.linear2(output)
        output = self.dropout(output)
        output = self.linear3(output)
        
        return output

# %%
model = CNN()
learning_rate = 0.005
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
criterion = nn.CrossEntropyLoss()

# %%
# hypereparameters
num_epochs = 50
n_total_steps = len(train_loader)

# %%
total_losses = []
total_loss = 0
print_steps = 300
loss_step = 25
for epoch in range(num_epochs):
    for i, (feature, label) in enumerate(train_loader):
        
        feature = feature.to(device)
        label = label.to(device)
        feature = feature.view(batch_size, 1, 88, 300)
        
        #forward pass
        outputs = model(feature.float())
        loss = criterion(outputs, label)
        total_loss += loss
        
        #back prop
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        #log
        if (i + 1) % print_steps == 0:
            print(f'Loss: {total_losses[-1]} --- epoch: {epoch+1}, step: {i+1}/{n_total_steps}') 
            print(feature.size())
        if (i + 1) % loss_step == 0:
            avg_loss = total_loss / loss_step
            total_losses.append(avg_loss.item())
            total_loss = 0
# Out:
# Loss: 0.9169497489929199 --- epoch: 1, step: 300/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.9527873396873474 --- epoch: 1, step: 600/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.890043318271637 --- epoch: 2, step: 300/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.8417022228240967 --- epoch: 2, step: 600/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.8548072576522827 --- epoch: 3, step: 300/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.8468227386474609 --- epoch: 3, step: 600/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.737296998500824 --- epoch: 4, step: 300/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.6928794384002686 --- epoch: 4, step: 600/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.815560519695282 --- epoch: 5, step: 300/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.7485315799713135 --- epoch: 5, step: 600/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.8387159705162048 --- epoch: 6, step: 300/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.6363314986228943 --- epoch: 6, step: 600/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.817993700504303 --- epoch: 7, step: 300/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.7140586972236633 --- epoch: 7, step: 600/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.6464861035346985 --- epoch: 8, step: 300/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.7085811495780945 --- epoch: 8, step: 600/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.760744035243988 --- epoch: 9, step: 300/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.5960529446601868 --- epoch: 9, step: 600/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.6309158802032471 --- epoch: 10, step: 300/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.6281917691230774 --- epoch: 10, step: 600/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.7075613141059875 --- epoch: 11, step: 300/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.5118007063865662 --- epoch: 11, step: 600/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.6349384188652039 --- epoch: 12, step: 300/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.7372207641601562 --- epoch: 12, step: 600/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.7795383334159851 --- epoch: 13, step: 300/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.6199808120727539 --- epoch: 13, step: 600/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.7255143523216248 --- epoch: 14, step: 300/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.7156796455383301 --- epoch: 14, step: 600/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.7537795305252075 --- epoch: 15, step: 300/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.5764652490615845 --- epoch: 15, step: 600/800
# torch.Size([5, 1, 88, 300])
# Loss: 0.
            predictions.append(i.item())
        for i in label:
            labels.append(i.item())

# %%
accuracy = accuracy_score(predictions, labels)

# %%
accuracy
# Out:
# 0.6690307328605201

# %%
confusion = confusion_matrix(predictions, labels)

# %%
def log_model(model, acc, **params):
    log_entry = {
        "model": model.state_dict(),
        "accuracy": acc,
    }
    
    for i in params:
        log_entry[i] = params[i]
    
    model_log.append(log_entry)

# %%
params = {
    "model_name": "CNN",
    "layers": ["Conv", "MaxPool", "Linear", "Linear", "Linear"],
    "hidden_sizes": [None, None, 64, 64, 3],
    "activation": [None, None, None, None, None],
    "dropout": [None, None, 0.2, 0.2, None],
    "optimizer": "SGD",
    "learning_rate": 0.03,
    "epochs": 50,
    "confusion_matrix": confusion,
    "notes": "changed convolution to (3,300)"
}

# %%
log_model(model, accuracy, **params)

# %%
pd.DataFrame().from_dict(model_log)
# Out:
#                                                 model  accuracy  \
# 0   (CountVectorizer(), LogisticRegression(C=1, ma...  0.785567
# 1   (CountVectorizer(), LogisticRegression(C=0.55,...  0.785567
# 2   (CountVectorizer(), XGBClassifier(base_score=0...  0.784536
# 3   {'conv1.weight': [[tensor([[-1.3640e-01,  5.65...  0.669031
# 4   {'conv1.weight': [[tensor([[ 2.8236e-01, -3.37...  0.683215
# 5   {'conv1.weight': [[tensor([[-0.3670, -0.0061, ...  0.658392
# 6   {'conv1.weight': [[tensor([[ 1.4144e+00,  4.39...  0.666667
# 7   {'conv1.weight': [[tensor([[ 0.3316,  0.0229, ...  0.669031
# 8   {'conv1.weight': [[tensor([[ 3.4375e-01,  1.50...  0.670213
# 9   {'conv1.weight': [[tensor([[ 0.3271,  0.0599, ...  0.667849
# 10  {'conv1.weight': [[tensor([[-0.3560, -0.0430, ...  0.674941
# 11  {'conv1.weight': [[tensor([[-0.2501,  0.0097, ...  0.659574
# 12  {'conv1.weight': [[tensor([[-2.0325e-01, -4.86...  0.669031
# 13  {'conv1.weight': [[tensor([[ 2.3637e-01, -7.41...  0.669031
# 14  {'conv1.weight': [[tensor([[ 2.3637e-01, -7.41...  0.669031
#
#              model_name penalty     C solver  \
# 0   logistic regression      l2  1.00  lbfgs
# 1   logistic regression      l2  0.55    sag
# 2         XGBClassifier     NaN   NaN    NaN
# 3                   CNN     NaN   NaN    NaN
# 4                   CNN     NaN   NaN    NaN
# 5                   CNN     NaN   NaN    NaN
# 6                   CNN     NaN   NaN    NaN
# 7                   CNN     NaN   NaN    NaN
# 8                   CNN     NaN   NaN    NaN
# 9                   CNN     NaN   NaN    NaN
# 10                  CNN     NaN   NaN    NaN
# 11                  CNN     NaN   NaN    NaN
# 12                  CNN     NaN   NaN    NaN
# 13                  CNN     NaN   NaN    NaN
# 14                  CNN     NaN   NaN    NaN
#
#                                 confusion_matrix  \
# 0    [[71, 10, 6], [40, 516, 97], [11, 44, 175]]
# 1    [[71, 10, 6], [40, 516, 97], [11, 44, 175]]
# 2    [[70, 9, 5], [41, 525, 107], [11, 36, 166]]
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9   [[11, 1, 11], [40, 434, 113], [67, 49, 120]]
# 10   [[12, 1, 11], [36, 424, 98], [70, 59, 135]]
# 11   [[15, 3, 12], [33, 396, 85], [70, 85, 147]]
# 12     [[7, 1, 3], [57, 466, 148], [54, 17, 93]]
# 13     [[7, 1, 3], [57, 466, 148], [54, 17, 93]]
# 14     [[7, 1, 3], [57, 466, 148], [54, 17, 93]]
#
#                                      layers             hidden_sizes  \
# 0                                       NaN                      NaN
# 1                                       NaN                      NaN
# 2                                       NaN                      NaN
# 3                   [Conv, MaxPool, Linear]       [None, None, None]
# 4                   [Conv, MaxPool, Linear]       [None, None, None]
# 5                   [Conv, MaxPool, Linear]       [None, None, None]
# 6                   [Conv, MaxPool, Linear]       [None, None, None]
# 7           [Conv, MaxPool, Linear, Linear]      [None, None, 64, 3]
# 8           [Conv, MaxPool, Linear, Linear]      [None, None, 64, 3]
# 9   [Conv, MaxPool, Linear, Linear, Linear]  [None, None, 64, 64, 3]
# 10  [Conv, MaxPool, Linear, Linear, Linear]  [None, None, 64, 64, 3]
# 11  [Conv, MaxPool, Linear, Linear, Linear]  [None, None, 64, 64, 3]
# 12  [Conv, MaxPool, Linear, Linear, Linear]  [None, None, 64, 64, 3]
# 13  [Conv, MaxPool, Linear, Linear, Linear]  [None, None, 64, 64, 3]
# 14  [Conv, MaxPool, Linear, Linear, Linear]  [None, None, 64, 64, 3]
#
#                         activation                        dropout optimizer  \
# 0                              NaN                            NaN       NaN
# 1                              NaN                            NaN       NaN
# 2                              NaN                            NaN       NaN
# 3               [None, None, None]             [None, None, None]       SGD
# 4               [None, None, None]             [None, None, None]       SGD
# 5               [None, None, None]             [None, None, None]       SGD
# 6               [None, None, None]             [None, None, None]      Adam
# 7         [None, None, None, None]       [None, None, None, None]       SGD
# 8         [None, None, None, None]       [None, None, None, None]       SGD
# 9   [None, None, None, None, None]  [None, None, 0.2, None, None]       SGD
# 10  [None, None, None, None, None]   [None, None, 0.2, 0.2, None]       SGD
# 11  [None, None, None, None, None]   [None, None, 0.2, 0.2, None]       SGD
# 12  [None, None, None, None, None]   [None, None, 0.2, 0.2, None]       SGD
# 13  [None, None, None, None, None]   [None, None, 0.2, 0.2, None]       SGD
# 14  [None, None, None, None, None]   [None, None, 0.2, 0.2, None]       SGD
#
#     learning_rate  epochs                                              notes
# 0             NaN     NaN                                                NaN
# 1             NaN     NaN                                                NaN
# 2             NaN     NaN                                                NaN
# 3           0.001    50.0  Baseline CNN Overfits and doesn't backpropagat...
# 4           0.003    50.0       Increased learning rate due to slow training
# 5           0.050    50.0  Increased learning rate again after small impr...
# 6           0.050    50.0                          Changed optimizer to Adam
# 7           0.050    50.0                                 Added Linear layer
# 8           0.050    50.0                                 Added Linear layer
# 9           0.050    50.0   Added Dropout layer after the first linear layer
# 10          0.050    50.0                        Added another dropout layer
# 11          0.050    50.0                     changed convolution to (2,300)
# 12          0.030    50.0                     changed convolution to (2,300)
# 13          0.030    50.0                     changed convolution to (3,300)
# 14          0.030    50.0                     changed convolution to (3,300)

# %%
# Save new model log
torch.save(model_log, "Objects/Models/model_log.pt")
